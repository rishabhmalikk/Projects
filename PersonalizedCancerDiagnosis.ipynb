# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <img src='https://daxg39y63pxwu.cloudfront.net/hackerday_banner/hq/personalized-medicine-redefining-cancer-treatment.jpg'></img>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 304.487926 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_index()
test_class_distribution = test_df['Class'].value_counts().sort_index()
cv_class_distribution = cv_df['Class'].value_counts().sort_index()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>PDF And CDF

# %%
import numpy as np
from pylab import *
import pylab
counts,bin_edges = np.histogram(train_class_distribution , bins=5 , density=True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
pylab.title('Distribution of Train Data')
# Plot both
plot(pdf,'-r',label='PDF')
plot(cdf,label='CDF')
pylab.legend(loc='upper left')
show()

# %%
import numpy as np
from pylab import *
import pylab
counts,bin_edges = np.histogram(test_class_distribution , bins=5 , density=True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
pylab.title('Distribution of Test Data')
# Plot both
plot(pdf,'-r',label='PDF')
plot(cdf,label='CDF')
pylab.legend(loc='upper left')
show()

# %%
import numpy as np
from pylab import *
import pylab
counts,bin_edges = np.histogram(cv_class_distribution , bins=5 , density=True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
pylab.title('Distribution of CV Data')
# Plot both
plot(pdf,'-r',label='PDF')
plot(cdf,label='CDF')
pylab.legend(loc='upper left')
show()

# %% [markdown]
# <b>Observation From PDF and CDF
#
#  We Can see from the above plots that our train,test,cv data have similar distribution

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.516679741623652
# Log loss on Test Data using Random Model 2.4501202748349167
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 227
# BRCA1     167
# TP53      110
# EGFR       92
# BRCA2      91
# PTEN       81
# KIT        67
# BRAF       63
# ALK        47
# PDGFRA     46
# ERBB2      42
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 227 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(max_features=1000)
train_gene_feature_tfidf = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_tfidf = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_tfidf = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2881    BRCA2
# 1307     MLH1
# 1309     MLH1
# 243      EGFR
# 604     SMAD4
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1a',
#  'arid2',
#  'arid5b',
#  'asxl1',
#  'asxl2',
#  'atm',
#  'atr',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axin1',
#  'axl',
#  'b2m',
#  'bap1',
#  'bcl10',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brd4',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'epcam',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'errfi1',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt1',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxo1',
#  'foxp1',
#  'gata3',
#  'gli1',
#  'gna11',
#  'gnaq',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'il7r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'kdm5c',
#  'kdm6a',
#  'kdr',
#  'keap1',
#  'kit',
#  'klf4',
#  'kmt2a',
#  'kmt2c',
#  'knstrn',
#  'kras',
#  'lats1',
#  'lats2',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm2',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'myd88',
#  'myod1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'npm1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms1',
#  'pms2',
#  'pole',
#  'ppm1d',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad21',
#  'rad50',
#  'rad51c',
#  'rad54l',
#  'raf1',
#  'rara',
#  'rasa1',
#  'rb1',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rit1',
#  'rnf43',
#  'ros1',
#  'rras2',
#  'runx1',
#  'rxra',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'shoc2',
#  'shq1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'srsf2',
#  'stat3',
#  'stk11',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vhl',
#  'whsc1',
#  'whsc1l1',
#  'xpo1',
#  'xrcc2',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 237)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.40374631665063
# For values of alpha =  0.0001 The log loss is: 1.2187768754019246
# For values of alpha =  0.001 The log loss is: 1.234222432301071
# For values of alpha =  0.01 The log loss is: 1.3305480692330667
# For values of alpha =  0.1 The log loss is: 1.447914499077223
# For values of alpha =  1 The log loss is: 1.4896548236494351
# For values of best alpha =  0.0001 The train log loss is: 1.044869698864562
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2187768754019246
# For values of best alpha =  0.0001 The test log loss is: 1.175804516179587

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  238  genes in train dataset?
# Ans
# 1. In test data 643 out of 665 : 96.69172932330827
# 2. In cross validation data 522 out of  532 : 98.1203007518797

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1923
# Truncating_Mutations    59
# Amplification           47
# Deletion                46
# Fusions                 25
# Overexpression           5
# Q61L                     3
# Q61H                     3
# E17K                     3
# Q209L                    2
# G13D                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1923 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02777778 0.04990584 0.07156309 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(max_features=1000)
train_variation_feature_tfidf = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_tfidf = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_tfidf = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1954)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.743752509385154
# For values of alpha =  0.0001 The log loss is: 1.7317862726459927
# For values of alpha =  0.001 The log loss is: 1.7293412866192919
# For values of alpha =  0.01 The log loss is: 1.7379059590240988
# For values of alpha =  0.1 The log loss is: 1.7419403806987475
# For values of alpha =  1 The log loss is: 1.7425537273820977
# For values of best alpha =  0.001 The train log loss is: 1.0976813129544578
# For values of best alpha =  0.001 The cross validation log loss is: 1.7293412866192919
# For values of best alpha =  0.001 The test log loss is: 1.6930535986092237

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1923  genes in test and cross validation data sets?
# Ans
# 1. In test data 75 out of 665 : 11.278195488721805
# 2. In cross validation data 45 out of  532 : 8.458646616541353

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(min_df=3,max_features=1000)
train_text_feature_tfidf = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_tfidf.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_tfidf = normalize(train_text_feature_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_tfidf = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_tfidf = normalize(test_text_feature_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_tfidf = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_tfidf = normalize(cv_text_feature_tfidf, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({3: 4525, 4: 3667, 5: 2528, 6: 2486, 8: 2238, 7: 2197, 9: 1947, 10: 1222, 11: 1159, 13: 1132, 12: 1082, 14: 887, 16: 810, 18: 787, 15: 746, 17: 679, 20: 548, 19: 519, 21: 507, 24: 476, 22: 421, 27: 411, 30: 407, 25: 403, 23: 401, 28: 370, 44: 362, 26: 358, 29: 286, 32: 284, 31: 269, 36: 264, 50: 254, 33: 249, 35: 244, 40: 229, 41: 225, 42: 215, 45: 214, 37: 211, 34: 199, 48: 193, 39: 188, 38: 188, 49: 168, 43: 160, 56: 159, 54: 147, 52: 145, 51: 142, 47: 141, 46: 135, 63: 132, 64: 131, 60: 129, 57: 125, 62: 121, 59: 119, 58: 119, 65: 117, 53: 112, 61: 111, 73: 108, 55: 107, 70: 103, 66: 103, 88: 99, 72: 99, 68: 93, 67: 92, 91: 89, 80: 85, 94: 82, 75: 82, 74: 82, 76: 81, 78: 79, 81: 77, 69: 75, 85: 72, 82: 71, 93: 69, 71: 69, 84: 67, 96: 66, 83: 65, 90: 64, 86: 64, 105: 63, 79: 63, 77: 63, 92: 62, 89: 61, 95: 60, 104: 58, 100: 58, 97: 56, 107: 54, 112: 52, 108: 51, 106: 51, 87: 50, 131: 49, 120: 49, 110: 49, 102: 49, 132: 48, 99: 48, 98: 48, 119: 46, 128: 45, 117: 45, 129: 44, 114: 44, 140: 43, 127: 43, 101: 43, 124: 42, 123: 42, 115: 41, 111: 41, 135: 40, 125: 40, 144: 39, 143: 39, 137: 39, 126: 39, 109: 39, 141: 37, 121: 37, 118: 37, 116: 37, 138: 36, 130: 36, 122: 36, 103: 36, 165: 35, 139: 34, 157: 33, 145: 33, 162: 32, 160: 32, 146: 32, 170: 31, 156: 31, 203: 30, 153: 30, 151: 30, 134: 30, 136: 29, 113: 29, 180: 28, 184: 27, 175: 27, 164: 27, 154: 27, 152: 27, 147: 27, 133: 27, 210: 26, 209: 26, 205: 26, 191: 26, 183: 26, 168: 26, 163: 26, 149: 26, 142: 26, 222: 25, 188: 25, 166: 25, 159: 25, 150: 25, 263: 24, 172: 24, 169: 24, 216: 23, 197: 23, 182: 23, 177: 23, 158: 23, 148: 23, 290: 22, 220: 22, 213: 22, 208: 22, 207: 22, 176: 22, 173: 22, 155: 22, 293: 21, 252: 21, 217: 21, 212: 21, 206: 21, 198: 21, 181: 21, 267: 20, 245: 20, 242: 20, 211: 20, 202: 20, 196: 20, 171: 20, 167: 20, 297: 19, 247: 19, 228: 19, 224: 19, 174: 19, 161: 19, 281: 18, 280: 18, 278: 18, 264: 18, 219: 18, 200: 18, 199: 18, 192: 18, 189: 18, 186: 18, 178: 18, 321: 17, 289: 17, 241: 17, 238: 17, 237: 17, 233: 17, 215: 17, 194: 17, 308: 16, 306: 16, 296: 16, 294: 16, 227: 16, 226: 16, 223: 16, 218: 16, 193: 16, 190: 16, 348: 15, 275: 15, 256: 15, 251: 15, 239: 15, 232: 15, 204: 15, 179: 15, 399: 14, 382: 14, 353: 14, 328: 14, 284: 14, 276: 14, 258: 14, 235: 14, 225: 14, 201: 14, 397: 13, 310: 13, 307: 13, 305: 13, 285: 13, 249: 13, 234: 13, 231: 13, 230: 13, 229: 13, 195: 13, 185: 13, 413: 12, 368: 12, 352: 12, 332: 12, 330: 12, 324: 12, 316: 12, 313: 12, 287: 12, 277: 12, 271: 12, 250: 12, 243: 12, 240: 12, 236: 12, 221: 12, 187: 12, 400: 11, 326: 11, 304: 11, 295: 11, 292: 11, 283: 11, 274: 11, 273: 11, 265: 11, 260: 11, 257: 11, 255: 11, 248: 11, 214: 11, 430: 10, 384: 10, 380: 10, 373: 10, 362: 10, 360: 10, 357: 10, 355: 10, 339: 10, 325: 10, 318: 10, 312: 10, 291: 10, 268: 10, 266: 10, 253: 10, 246: 10, 552: 9, 501: 9, 490: 9, 453: 9, 432: 9, 424: 9, 408: 9, 385: 9, 376: 9, 350: 9, 317: 9, 311: 9, 309: 9, 300: 9, 298: 9, 261: 9, 641: 8, 543: 8, 515: 8, 508: 8, 474: 8, 463: 8, 444: 8, 438: 8, 434: 8, 433: 8, 420: 8, 409: 8, 407: 8, 396: 8, 374: 8, 371: 8, 363: 8, 358: 8, 347: 8, 334: 8, 329: 8, 322: 8, 301: 8, 299: 8, 288: 8, 272: 8, 270: 8, 254: 8, 244: 8, 622: 7, 615: 7, 592: 7, 588: 7, 587: 7, 576: 7, 568: 7, 549: 7, 510: 7, 507: 7, 499: 7, 497: 7, 492: 7, 481: 7, 480: 7, 460: 7, 456: 7, 450: 7, 442: 7, 437: 7, 428: 7, 423: 7, 422: 7, 418: 7, 411: 7, 403: 7, 393: 7, 387: 7, 378: 7, 370: 7, 365: 7, 359: 7, 356: 7, 351: 7, 349: 7, 342: 7, 341: 7, 338: 7, 336: 7, 335: 7, 320: 7, 319: 7, 302: 7, 286: 7, 282: 7, 279: 7, 1660: 6, 1350: 6, 912: 6, 845: 6, 802: 6, 774: 6, 717: 6, 716: 6, 708: 6, 694: 6, 653: 6, 652: 6, 628: 6, 614: 6, 605: 6, 596: 6, 586: 6, 585: 6, 541: 6, 539: 6, 536: 6, 523: 6, 516: 6, 511: 6, 498: 6, 496: 6, 494: 6, 493: 6, 485: 6, 472: 6, 470: 6, 469: 6, 461: 6, 454: 6, 441: 6, 436: 6, 426: 6, 417: 6, 406: 6, 402: 6, 401: 6, 395: 6, 392: 6, 383: 6, 381: 6, 379: 6, 377: 6, 372: 6, 369: 6, 346: 6, 344: 6, 343: 6, 340: 6, 32 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3758916435681192
# For values of alpha =  0.0001 The log loss is: 1.3212143944252894
# For values of alpha =  0.001 The log loss is: 1.1967589578908395
# For values of alpha =  0.01 The log loss is: 1.2974748842176105
# For values of alpha =  0.1 The log loss is: 1.5236355207443326
# For values of alpha =  1 The log loss is: 1.703884230239202
# For values of best alpha =  0.001 The train log loss is: 0.8078441949329335
# For values of best alpha =  0.001 The cross validation log loss is: 1.1967589578908395
# For values of best alpha =  0.001 The test log loss is: 1.1499192258667368

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 94.109 % of word of test data appeared in train data
# 97.438 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_tfidf_vec = TfidfVectorizer(max_features=1000)
    var_tfidf_vec = TfidfVectorizer(max_features=1000)
    text_tfidf_vec = TfidfVectorizer(min_df=3 , max_features=1000)
    
    gene_vec = gene_tfidf_vec.fit(train_df['Gene'])
    var_vec  = var_tfidf_vec.fit(train_df['Variation'])
    text_vec = text_tfidf_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_tfidf_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]
gene_vectorizer = TfidfVectorizer(max_features=1000)
train_gene_feature_tfidf = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_tfidf = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_tfidf = gene_vectorizer.transform(cv_df['Gene'])
variation_vectorizer = TfidfVectorizer(max_features=1000)
train_variation_feature_tfidf = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_tfidf = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_tfidf = variation_vectorizer.transform(cv_df['Variation'])
text_vectorizer = TfidfVectorizer(min_df=3 , max_features=1000)
train_text_feature_tfidf = text_vectorizer.fit_transform(train_df['TEXT'])
# don't forget to normalize every feature
train_text_feature_tfidf = normalize(train_text_feature_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_tfidf = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_tfidf = normalize(test_text_feature_tfidf, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_tfidf = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_tfidf = normalize(cv_text_feature_tfidf, axis=0)


train_gene_var_tfidf = hstack((train_gene_feature_tfidf,train_variation_feature_tfidf))
test_gene_var_tfidf = hstack((test_gene_feature_tfidf,test_variation_feature_tfidf))
cv_gene_var_tfidf = hstack((cv_gene_feature_tfidf,cv_variation_feature_tfidf))

train_x_tfidf = hstack((train_gene_var_tfidf, train_text_feature_tfidf)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_tfidf = hstack((test_gene_var_tfidf, test_text_feature_tfidf)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_tfidf = hstack((cv_gene_var_tfidf, cv_text_feature_tfidf)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("Tfidf features :")
print("(number of data points * number of features) in train data = ", train_x_tfidf.shape)
print("(number of data points * number of features) in test data = ", test_x_tfidf.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_tfidf.shape)
# Out:
# Tfidf features :
# (number of data points * number of features) in train data =  (2124, 2237)
# (number of data points * number of features) in test data =  (665, 2237)
# (number of data points * number of features) in cross validation data = (532, 2237)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)


predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2049546277834813
# for alpha = 0.0001
# Log Loss : 1.2049728494860523
# for alpha = 0.001
# Log Loss : 1.204081274622561
# for alpha = 0.1
# Log Loss : 1.2251217752692654
# for alpha = 1
# Log Loss : 1.2409452335327338
# for alpha = 10
# Log Loss : 1.4011464360300012
# for alpha = 100
# Log Loss : 1.4221235073711722
# for alpha = 1000
# Log Loss : 1.4246237492725122
# For values of best alpha =  0.001 The train log loss is: 0.772651197246441
# For values of best alpha =  0.001 The cross validation log loss is: 1.204081274622561
# For values of best alpha =  0.001 The test log loss is: 1.1516128072167406

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_tfidf)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_tfidf.toarray()))
# Out:
# Log Loss : 1.204081274622561
# Number of missclassified point : 0.39473684210526316
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, InCorrectly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0828 0.486  0.1605 0.0757 0.0446 0.0411 0.0991 0.0054 0.0048]]
# Actual Class : 3
# --------------------------------------------------
# 15 Text feature [treatment] present in test data point [True]
# 16 Text feature [patients] present in test data point [True]
# 18 Text feature [clinical] present in test data point [True]
# 20 Text feature [12] present in test data point [True]
# 21 Text feature [molecular] present in test data point [True]
# 23 Text feature [11] present in test data point [True]
# 25 Text feature [therapy] present in test data point [True]
# 26 Text feature [recently] present in test data point [True]
# 27 Text feature [study] present in test data point [True]
# 28 Text feature [18] present in test data point [True]
# 29 Text feature [time] present in test data point [True]
# 30 Text feature [15] present in test data point [True]
# 32 Text feature [also] present in test data point [True]
# 33 Text feature [may] present in test data point [True]
# 34 Text feature [different] present in test data point [True]
# 35 Text feature [however] present in test data point [True]
# 36 Text feature [treated] present in test data point [True]
# 37 Text feature [including] present in test data point [True]
# 38 Text feature [17] present in test data point [True]
# 39 Text feature [first] present in test data point [True]
# 40 Text feature [using] present in test data point [True]
# 41 Text feature [10] present in test data point [True]
# 43 Text feature [detection] present in test data point [True]
# 44 Text feature [one] present in test data point [True]
# 45 Text feature [20] present in test data point [True]
# 47 Text feature [13] present in test data point [True]
# 48 Text feature [patient] present in test data point [True]
# 49 Text feature [19] present in test data point [True]
# 51 Text feature [studies] present in test data point [True]
# 52 Text feature [progression] present in test data point [True]
# 53 Text feature [reported] present in test data point [True]
# 54 Text feature [median] present in test data point [True]
# 55 Text feature [confirmed] present in test data point [True]
# 56 Text feature [gene] present in test data point [True]
# 60 Text feature [observed] present in test data point [True]
# 61 Text feature [respectively] present in test data point [True]
# 62 Text feature [table] present in test data point [True]
# 63 Text feature [present] present in test data point [True]
# 65 Text feature [disease] present in test data point [True]
# 66 Text feature [found] present in test data point [True]
# 67 Text feature [several] present in test data point [True]
# 69 Text feature [mutation] present in test data point [True]
# 70 Text feature [common] present in test data point [True]
# 71 Text feature [shown] present in test data point [True]
# 72 Text feature [analysis] present in test data point [True]
# 73 Text feature [according] present in test data point [True]
# 74 Text feature [identified] present in test data point [True]
# 75 Text feature [mutations] present in test data point [True]
# 76 Text feature [performed] present in test data point [True]
# 78 Text feature [fusion] present in test data point [True]
# 79 Text feature [rearrangements] present in test data point [True]
# 80 Text feature [primary] present in test data point [True]
# 81 Text feature [described] present in test data point [True]
# 82 Text feature [small] present in test data point [True]
# 83 Text feature [followed] present in test data point [True]
# 84 Text feature [tissue] present in test data point [True]
# 85 Text feature [16] present in test data point [True]
# 88 Text feature [due] present in test data point [True]
# 89 Text feature [overall] present in test data point [True]
# 90 Text feature [positive] present in test data point [True]
# 91 Text feature [previously] present in test data point [True]
# 92 Text feature [pcr] present in test data point [True]
# 93 Text feature [two] present in test data point [True]
# 94 Text feature [higher] present in test data point [True]
# 96 Text feature [detected] present in test data point [True]
# 97 Text feature [results] present in test data point [True]
# 98 Text feature [specific] present in test data point [True]
# 99 Text feature [discussion] present in test data point [True]
# Out of the top  100  features  68 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, correctly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0698 0.1033 0.0153 0.0644 0.0372 0.0346 0.6669 0.0046 0.0038]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [activation] present in test data point [True]
# 18 Text feature [activated] present in test data point [True]
# 19 Text feature [cells] present in test data point [True]
# 20 Text feature [downstream] present in test data point [True]
# 21 Text feature [kinase] present in test data point [True]
# 24 Text feature [expressing] present in test data point [True]
# 25 Text feature [inhibitor] present in test data point [True]
# 26 Text feature [signaling] present in test data point [True]
# 27 Text feature [also] present in test data point [True]
# 28 Text feature [contrast] present in test data point [True]
# 29 Text feature [activating] present in test data point [True]
# 30 Text feature [well] present in test data point [True]
# 31 Text feature [growth] present in test data point [True]
# 32 Text feature [10] present in test data point [True]
# 33 Text feature [addition] present in test data point [True]
# 34 Text feature [independent] present in test data point [True]
# 35 Text feature [factor] present in test data point [True]
# 36 Text feature [compared] present in test data point [True]
# 37 Text feature [shown] present in test data point [True]
# 38 Text feature [however] present in test data point [True]
# 39 Text feature [similar] present in test data point [True]
# 40 Text feature [cell] present in test data point [True]
# 41 Text feature [higher] present in test data point [True]
# 42 Text feature [mutations] present in test data point [True]
# 43 Text feature [previously] present in test data point [True]
# 44 Text feature [inhibitors] present in test data point [True]
# 45 Text feature [constitutive] present in test data point [True]
# 46 Text feature [increased] present in test data point [True]
# 47 Text feature [mechanism] present in test data point [True]
# 48 Text feature [treatment] present in test data point [True]
# 49 Text feature [oncogenic] present in test data point [True]
# 50 Text feature [recently] present in test data point [True]
# 51 Text feature [sensitive] present in test data point [True]
# 52 Text feature [presence] present in test data point [True]
# 53 Text feature [treated] present in test data point [True]
# 54 Text feature [found] present in test data point [True]
# 55 Text feature [showed] present in test data point [True]
# 56 Text feature [may] present in test data point [True]
# 57 Text feature [activate] present in test data point [True]
# 58 Text feature [without] present in test data point [True]
# 59 Text feature [suggest] present in test data point [True]
# 60 Text feature [enhanced] present in test data point [True]
# 61 Text feature [pathways] present in test data point [True]
# 62 Text feature [potential] present in test data point [True]
# 63 Text feature [different] present in test data point [True]
# 67 Text feature [fig] present in test data point [True]
# 68 Text feature [increase] present in test data point [True]
# 69 Text feature [although] present in test data point [True]
# 70 Text feature [mutation] present in test data point [True]
# 71 Text feature [absence] present in test data point [True]
# 72 Text feature [constitutively] present in test data point [True]
# 73 Text feature [serum] present in test data point [True]
# 74 Text feature [inhibition] present in test data point [True]
# 75 Text feature [interestingly] present in test data point [True]
# 76 Text feature [phosphorylation] present in test data point [True]
# 77 Text feature [3b] present in test data point [True]
# 78 Text feature [observed] present in test data point [True]
# 79 Text feature [described] present in test data point [True]
# 80 Text feature [results] present in test data point [True]
# 81 Text feature [total] present in test data point [True]
# 82 Text feature [studies] present in test data point [True]
# 83 Text feature [proliferation] present in test data point [True]
# 84 Text feature [mutant] present in test data point [True]
# 85 Text feature [using] present in test data point [True]
# 86 Text feature [figure] present in test data point [True]
# 87 Text feature [24] present in test data point [True]
# 88 Text feature [3a] present in test data point [True]
# 89 Text feature [pathway] present in test data point [True]
# 90 Text feature [discussion] present in test data point [True]
# 91 Text feature [respectively] present in test data point [True]
# 92 Text feature [active] present in test data point [True]
# 93 Text feature [tyrosine] present in test data point [True]
# 94 Text feature [2b] present in test data point [True]
# 95 Text feature [examined] present in test data point [True]
# 96 Text feature [various] present in test data point [True]
# 97 Text feature [consistent] present in test data point [True]
# 98 Text feature [two] present in test data point [True]
# 99 Text feature [20] present in test data point [True]
# Out of the top  100  features  78 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.082252249892834
# for alpha = 11
# Log Loss : 1.0346838695752207
# for alpha = 15
# Log Loss : 1.0593215586792144
# for alpha = 21
# Log Loss : 1.0757649615207328
# for alpha = 31
# Log Loss : 1.0848162682964977
# for alpha = 41
# Log Loss : 1.0904189417112773
# for alpha = 51
# Log Loss : 1.0984326905229855
# for alpha = 99
# Log Loss : 1.1237590152734738
# For values of best alpha =  11 The train log loss is: 0.6414670426223948
# For values of best alpha =  11 The cross validation log loss is: 1.0346838695752207
# For values of best alpha =  11 The test log loss is: 0.9954957546114923

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0346838695752207
# Number of mis-classified points : 0.35902255639097747
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 3
# The  11  nearest neighbours of the test points belongs to classes [3 2 7 6 7 1 7 7 2 7 2]
# Fequency of nearest points : Counter({7: 5, 2: 3, 3: 1, 6: 1, 1: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 7 7 7]
# Fequency of nearest points : Counter({7: 11})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.199320657200022
# for alpha = 1e-05
# Log Loss : 1.1323922530449673
# for alpha = 0.0001
# Log Loss : 1.0450175768255776
# for alpha = 0.001
# Log Loss : 1.0585061707678436
# for alpha = 0.01
# Log Loss : 1.2377124824021637
# for alpha = 0.1
# Log Loss : 1.6883287239369014
# for alpha = 1
# Log Loss : 1.7986348882636414
# for alpha = 10
# Log Loss : 1.810964134104606
# for alpha = 100
# Log Loss : 1.8124448519168412
# For values of best alpha =  0.0001 The train log loss is: 0.6021297311066035
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0450175768255776
# For values of best alpha =  0.0001 The test log loss is: 0.9621582778200072

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 1.0450175768255776
# Number of mis-classified points : 0.3308270676691729
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_tfidf.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. InCorrectly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.077  0.4591 0.1222 0.075  0.0281 0.0636 0.1704 0.0018 0.0028]]
# Actual Class : 3
# --------------------------------------------------
# 55 Text feature [01] present in test data point [True]
# 67 Text feature [detection] present in test data point [True]
# 87 Text feature [molecular] present in test data point [True]
# 97 Text feature [2007] present in test data point [True]
# 107 Text feature [90] present in test data point [True]
# 111 Text feature [statistical] present in test data point [True]
# 113 Text feature [rearrangements] present in test data point [True]
# 114 Text feature [treatment] present in test data point [True]
# 117 Text feature [exons] present in test data point [True]
# 118 Text feature [end] present in test data point [True]
# 121 Text feature [patient] present in test data point [True]
# 130 Text feature [fusion] present in test data point [True]
# 133 Text feature [treated] present in test data point [True]
# 134 Text feature [able] present in test data point [True]
# 139 Text feature [rate] present in test data point [True]
# 146 Text feature [group] present in test data point [True]
# 150 Text feature [therapy] present in test data point [True]
# 154 Text feature [products] present in test data point [True]
# 155 Text feature [54] present in test data point [True]
# 165 Text feature [value] present in test data point [True]
# 166 Text feature [specimens] present in test data point [True]
# 168 Text feature [tissue] present in test data point [True]
# 170 Text feature [biological] present in test data point [True]
# 179 Text feature [invitrogen] present in test data point [True]
# 183 Text feature [05] present in test data point [True]
# 184 Text feature [copy] present in test data point [True]
# 187 Text feature [conditions] present in test data point [True]
# 188 Text feature [given] present in test data point [True]
# 194 Text feature [samples] present in test data point [True]
# 204 Text feature [features] present in test data point [True]
# 206 Text feature [36] present in test data point [True]
# 210 Text feature [analyses] present in test data point [True]
# 213 Text feature [development] present in test data point [True]
# 214 Text feature [33] present in test data point [True]
# 216 Text feature [normal] present in test data point [True]
# 218 Text feature [followed] present in test data point [True]
# 225 Text feature [method] present in test data point [True]
# 226 Text feature [applied] present in test data point [True]
# 236 Text feature [patients] present in test data point [True]
# 238 Text feature [differentiation] present in test data point [True]
# 241 Text feature [volume] present in test data point [True]
# 242 Text feature [genes] present in test data point [True]
# 243 Text feature [rates] present in test data point [True]
# 248 Text feature [range] present in test data point [True]
# 249 Text feature [point] present in test data point [True]
# 252 Text feature [alone] present in test data point [True]
# 257 Text feature [using] present in test data point [True]
# 259 Text feature [since] present in test data point [True]
# 262 Text feature [potential] present in test data point [True]
# 263 Text feature [pcr] present in test data point [True]
# 264 Text feature [common] present in test data point [True]
# 266 Text feature [fusions] present in test data point [True]
# 267 Text feature [significance] present in test data point [True]
# 268 Text feature [number] present in test data point [True]
# 273 Text feature [would] present in test data point [True]
# 276 Text feature [different] present in test data point [True]
# 277 Text feature [types] present in test data point [True]
# 279 Text feature [based] present in test data point [True]
# 280 Text feature [30] present in test data point [True]
# 285 Text feature [myc] present in test data point [True]
# 288 Text feature [80] present in test data point [True]
# 291 Text feature [small] present in test data point [True]
# 293 Text feature [18] present in test data point [True]
# 298 Text feature [gene] present in test data point [True]
# 299 Text feature [finding] present in test data point [True]
# 300 Text feature [groups] present in test data point [True]
# 303 Text feature [correlation] present in test data point [True]
# 304 Text feature [affected] present in test data point [True]
# 306 Text feature [research] present in test data point [True]
# 307 Text feature [14] present in test data point [True]
# 311 Text feature [considered] present in test data point [True]
# 312 Text feature [testing] present in test data point [True]
# 316 Text feature [47] present in test data point [True]
# 317 Text feature [primary] present in test data point [True]
# 320 Text feature [cases] present in test data point [True]
# 321 Text feature [primers] present in test data point [True]
# 322 Text feature [included] present in test data point [True]
# 323 Text feature [among] present in test data point [True]
# 325 Text feature [forms] present in test data point [True]
# 328 Text feature [american] present in test data point [True]
# 330 Text feature [time] present in test data point [True]
# 333 Text feature [clinical] present in test data point [True]
# 334 Text feature [events] present in test data point [True]
# 335 Text feature [isolated] present in test data point [True]
# 336 Text feature [selected] present in test data point [True]
# 337 Text feature [previous] present in test data point [True]
# 338 Text feature [confirmed] present in test data point [True]
# 339 Text feature [met] present in test data point [True]
# 340 Text feature [expected] present in test data point [True]
# 341 Text feature [used] present in test data point [True]
# 342 Text feature [31] present in test data point [True]
# 343 Text feature [apoptosis] present in test data point [True]
# 345 Text feature [median] present in test data point [True]
# 346 Text feature [purified] present in test data point [True]
# 349 Text feature [university] present in test data point [True]
# 351 Text feature [observed] present in test data point [True]
# 355 Text feature [revealed] present in test data point [True]
# 356 Text feature [concentration] present in test data point [True]
# 357 Text feature [models] present in test data point [True]
# 359 Text feature [studies] present in test data point [True]
# 360 Text feature [regulation] present in test data point [True]
# 362 Text feature [46] present in test data point [True]
# 363 Text feature [carried] present in test data point [True]
# 365 Text feature [51] present in test data point [True]
# 366 Text feature [nm] present in test data point [True]
# 369 Text feature [factors] present in test data point [True]
# 372 Text feature [enzyme] present in test data point [True]
# 374 Text feature [28] present in test data point [True]
# 375 Text feature [ca] present in test data point [True]
# 378 Text feature [34] present in test data point [True]
# 380 Text feature [16] present in test data point [True]
# 383 Text feature [study] present in test data point [True]
# 384 Text feature [presented] present in test data point [True]
# 386 Text feature [direct] present in test data point [True]
# 391 Text feature [http] present in test data point [True]
# 392 Text feature [may] present in test data point [True]
# 395 Text feature [unknown] present in test data point [True]
# 396 Text feature [15] present in test data point [True]
# 401 Text feature [stage] present in test data point [True]
# 402 Text feature [29] present in test data point [True]
# 408 Text feature [12] present in test data point [True]
# 409 Text feature [indicating] present in test data point [True]
# 412 Text feature [present] present in test data point [True]
# 413 Text feature [sample] present in test data point [True]
# 414 Text feature [known] present in test data point [True]
# 416 Text feature [sequencing] present in test data point [True]
# 418 Text feature [related] present in test data point [True]
# 419 Text feature [disease] present in test data point [True]
# 421 Text feature [control] present in test data point [True]
# 422 Text feature [data] present in test data point [True]
# 425 Text feature [ml] present in test data point [True]
# 429 Text feature [association] present in test data point [True]
# 431 Text feature [shows] present in test data point [True]
# 432 Text feature [59] present in test data point [True]
# 434 Text feature [model] present in test data point [True]
# 435 Text feature [lower] present in test data point [True]
# 436 Text feature [70] present in test data point [True]
# 437 Text feature [level] present in test data point [True]
# 443 Text feature [lung] present in test data point [True]
# 448 Text feature [fold] present in test data point [True]
# 449 Text feature [17] present in test data point [True]
# 451 Text feature [overexpression] present in test data point [True]
# 452 Text feature [role] present in test data point [True]
# 454 Text feature [evidence] present in test data point [True]
# 455 Text feature [performed] present in test data point [True]
# 459 Text feature [increase] present in test data point [True]
# 460 Text feature [recently] present in test data point [True]
# 462 Text feature [involved] present in test data point [True]
# 463 Text feature [screening] present in test data point [True]
# 464 Text feature [significant] present in test data point [True]
# 466 Text feature [specific] present in test data point [True]
# 468 Text feature [table] present in test data point [True]
# 470 Text feature [prostate] present in test data point [True]
# 472 Text feature [100] present in test data point [True]
# 473 Text feature [11] present in test data point [True]
# 475 Text feature [distribution] present in test data point [True]
# 477 Text feature [years] present in test data point [True]
# 483 Text feature [frame] present in test data point [True]
# 485 Text feature [20] present in test data point [True]
# 487 Text feature [due] present in test data point [True]
# 493 Text feature [seen] present in test data point [True]
# 495 Text feature [terminus] present in test data point [True]
# 498 Text feature [line] present in test data point [True]
# 499 Text feature [regulatory] present in test data point [True]
# Out of the top  500  features  164 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 101
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0319 0.3585 0.0018 0.1132 0.0088 0.0019 0.4811 0.0018 0.001 ]]
# Actual Class : 2
# --------------------------------------------------
# 7 Text feature [activation] present in test data point [True]
# 9 Text feature [overexpression] present in test data point [True]
# 14 Text feature [constitutive] present in test data point [True]
# 18 Text feature [oncogene] present in test data point [True]
# 29 Text feature [pathways] present in test data point [True]
# 31 Text feature [transformed] present in test data point [True]
# 37 Text feature [factor] present in test data point [True]
# 38 Text feature [activated] present in test data point [True]
# 43 Text feature [2a] present in test data point [True]
# 50 Text feature [000] present in test data point [True]
# 52 Text feature [phospho] present in test data point [True]
# 60 Text feature [inhibited] present in test data point [True]
# 63 Text feature [signaling] present in test data point [True]
# 66 Text feature [3b] present in test data point [True]
# 69 Text feature [activate] present in test data point [True]
# 74 Text feature [akt] present in test data point [True]
# 84 Text feature [oncogenic] present in test data point [True]
# 87 Text feature [regions] present in test data point [True]
# 88 Text feature [tissues] present in test data point [True]
# 91 Text feature [transforming] present in test data point [True]
# 92 Text feature [expressing] present in test data point [True]
# 113 Text feature [driven] present in test data point [True]
# 117 Text feature [coding] present in test data point [True]
# 129 Text feature [increased] present in test data point [True]
# 135 Text feature [per] present in test data point [True]
# 137 Text feature [fold] present in test data point [True]
# 141 Text feature [de] present in test data point [True]
# 149 Text feature [days] present in test data point [True]
# 172 Text feature [gfp] present in test data point [True]
# 177 Text feature [derived] present in test data point [True]
# 178 Text feature [without] present in test data point [True]
# 182 Text feature [example] present in test data point [True]
# 183 Text feature [sites] present in test data point [True]
# 185 Text feature [express] present in test data point [True]
# 194 Text feature [activating] present in test data point [True]
# 200 Text feature [phosphorylated] present in test data point [True]
# 207 Text feature [serum] present in test data point [True]
# 208 Text feature [2b] present in test data point [True]
# 215 Text feature [addition] present in test data point [True]
# 225 Text feature [versus] present in test data point [True]
# 227 Text feature [75] present in test data point [True]
# 232 Text feature [cells] present in test data point [True]
# 234 Text feature [promoter] present in test data point [True]
# 237 Text feature [supplemental] present in test data point [True]
# 240 Text feature [demonstrated] present in test data point [True]
# 241 Text feature [transformation] present in test data point [True]
# 243 Text feature [fig] present in test data point [True]
# 248 Text feature [61] present in test data point [True]
# 258 Text feature [hours] present in test data point [True]
# 259 Text feature [increase] present in test data point [True]
# 263 Text feature [interestingly] present in test data point [True]
# 269 Text feature [inhibitor] present in test data point [True]
# 272 Text feature [frequent] present in test data point [True]
# 277 Text feature [phosphate] present in test data point [True]
# 285 Text feature [distinct] present in test data point [True]
# 291 Text feature [form] present in test data point [True]
# 294 Text feature [72] present in test data point [True]
# 297 Text feature [factors] present in test data point [True]
# 299 Text feature [positive] present in test data point [True]
# 304 Text feature [lesions] present in test data point [True]
# 307 Text feature [survival] present in test data point [True]
# 313 Text feature [include] present in test data point [True]
# 317 Text feature [total] present in test data point [True]
# 318 Text feature [regulated] present in test data point [True]
# 321 Text feature [genomic] present in test data point [True]
# 324 Text feature [41] present in test data point [True]
# 331 Text feature [s3] present in test data point [True]
# 345 Text feature [assessed] present in test data point [True]
# 351 Text feature [concentrations] present in test data point [True]
# 353 Text feature [37] present in test data point [True]
# 357 Text feature [blood] present in test data point [True]
# 361 Text feature [phosphorylation] present in test data point [True]
# 365 Text feature [well] present in test data point [True]
# 370 Text feature [contrast] present in test data point [True]
# 371 Text feature [harboring] present in test data point [True]
# 374 Text feature [transcription] present in test data point [True]
# 375 Text feature [additional] present in test data point [True]
# 376 Text feature [comparison] present in test data point [True]
# 378 Text feature [cultured] present in test data point [True]
# 381 Text feature [gain] present in test data point [True]
# 384 Text feature [university] present in test data point [True]
# 387 Text feature [org] present in test data point [True]
# 391 Text feature [initial] present in test data point [True]
# 394 Text feature [position] present in test data point [True]
# 403 Text feature [contribute] present in test data point [True]
# 406 Text feature [chain] present in test data point [True]
# 407 Text feature [mechanisms] present in test data point [True]
# 410 Text feature [kd] present in test data point [True]
# 412 Text feature [mediated] present in test data point [True]
# 413 Text feature [44] present in test data point [True]
# 415 Text feature [caused] present in test data point [True]
# 425 Text feature [previously] present in test data point [True]
# 429 Text feature [promote] present in test data point [True]
# 430 Text feature [higher] present in test data point [True]
# 431 Text feature [similar] present in test data point [True]
# 434 Text feature [less] present in test data point [True]
# 436 Text feature [grade] present in test data point [True]
# 441 Text feature [mechanism] present in test data point [True]
# 447 Text feature [occur] present in test data point [True]
# 448 Text feature [3a] present in test data point [True]
# 449 Text feature [elevated] present in test data point [True]
# 451 Text feature [vector] present in test data point [True]
# 452 Text feature [tumors] present in test data point [True]
# 453 Text feature [loop] present in test data point [True]
# 454 Text feature [positions] present in test data point [True]
# 458 Text feature [mutant] present in test data point [True]
# 459 Text feature [stage] present in test data point [True]
# 462 Text feature [tyrosine] present in test data point [True]
# 466 Text feature [somatic] present in test data point [True]
# 467 Text feature [note] present in test data point [True]
# 469 Text feature [mouse] present in test data point [True]
# 473 Text feature [induction] present in test data point [True]
# 474 Text feature [sequences] present in test data point [True]
# 475 Text feature [lead] present in test data point [True]
# 476 Text feature [region] present in test data point [True]
# 479 Text feature [effective] present in test data point [True]
# 480 Text feature [strongly] present in test data point [True]
# 482 Text feature [corresponding] present in test data point [True]
# 483 Text feature [24] present in test data point [True]
# 484 Text feature [frequently] present in test data point [True]
# 486 Text feature [frequency] present in test data point [True]
# 487 Text feature [reverse] present in test data point [True]
# 489 Text feature [sensitive] present in test data point [True]
# 494 Text feature [tumor] present in test data point [True]
# 498 Text feature [features] present in test data point [True]
# 499 Text feature [free] present in test data point [True]
# Out of the top  500  features  126 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1914655667020118
# for alpha = 1e-05
# Log Loss : 1.173307267405365
# for alpha = 0.0001
# Log Loss : 1.0841911912991669
# for alpha = 0.001
# Log Loss : 1.1847871316052376
# for alpha = 0.01
# Log Loss : 1.4355080740593549
# for alpha = 0.1
# Log Loss : 1.695863878609213
# for alpha = 1
# Log Loss : 1.7767567514189444
# For values of best alpha =  0.0001 The train log loss is: 0.5970419466574897
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0841911912991669
# For values of best alpha =  0.0001 The test log loss is: 0.9760605385224307

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 1.0841911912991669
# Number of mis-classified points : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[2.700e-03 1.134e-01 7.000e-04 9.400e-03 1.100e-03 3.900e-03 8.670e-01
#   1.800e-03 1.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 8 Text feature [overexpression] present in test data point [True]
# 10 Text feature [codon] present in test data point [True]
# 20 Text feature [activation] present in test data point [True]
# 25 Text feature [oncogene] present in test data point [True]
# 27 Text feature [provided] present in test data point [True]
# 28 Text feature [factor] present in test data point [True]
# 32 Text feature [constitutive] present in test data point [True]
# 33 Text feature [her2] present in test data point [True]
# 39 Text feature [enhanced] present in test data point [True]
# 41 Text feature [2a] present in test data point [True]
# 45 Text feature [pathways] present in test data point [True]
# 50 Text feature [transformed] present in test data point [True]
# 52 Text feature [000] present in test data point [True]
# 59 Text feature [regions] present in test data point [True]
# 61 Text feature [inhibited] present in test data point [True]
# 64 Text feature [activated] present in test data point [True]
# 66 Text feature [phospho] present in test data point [True]
# 68 Text feature [increased] present in test data point [True]
# 77 Text feature [de] present in test data point [True]
# 78 Text feature [activate] present in test data point [True]
# 85 Text feature [bp] present in test data point [True]
# 88 Text feature [akt] present in test data point [True]
# 90 Text feature [3b] present in test data point [True]
# 98 Text feature [cdna] present in test data point [True]
# 99 Text feature [stably] present in test data point [True]
# 112 Text feature [downstream] present in test data point [True]
# 113 Text feature [adenocarcinoma] present in test data point [True]
# 121 Text feature [signaling] present in test data point [True]
# 123 Text feature [transforming] present in test data point [True]
# 129 Text feature [signals] present in test data point [True]
# 130 Text feature [derived] present in test data point [True]
# 138 Text feature [approximately] present in test data point [True]
# 139 Text feature [days] present in test data point [True]
# 147 Text feature [oncogenic] present in test data point [True]
# 148 Text feature [fold] present in test data point [True]
# 155 Text feature [per] present in test data point [True]
# 156 Text feature [signalling] present in test data point [True]
# 157 Text feature [primer] present in test data point [True]
# 158 Text feature [without] present in test data point [True]
# 159 Text feature [example] present in test data point [True]
# 160 Text feature [increase] present in test data point [True]
# 168 Text feature [sites] present in test data point [True]
# 173 Text feature [driven] present in test data point [True]
# 174 Text feature [expressing] present in test data point [True]
# 185 Text feature [gfp] present in test data point [True]
# 194 Text feature [2b] present in test data point [True]
# 196 Text feature [extracellular] present in test data point [True]
# 203 Text feature [phosphorylated] present in test data point [True]
# 207 Text feature [75] present in test data point [True]
# 210 Text feature [examined] present in test data point [True]
# 214 Text feature [positive] present in test data point [True]
# 218 Text feature [distinct] present in test data point [True]
# 219 Text feature [malignant] present in test data point [True]
# 221 Text feature [41] present in test data point [True]
# 222 Text feature [activating] present in test data point [True]
# 225 Text feature [versus] present in test data point [True]
# 226 Text feature [hours] present in test data point [True]
# 227 Text feature [genomic] present in test data point [True]
# 229 Text feature [fig] present in test data point [True]
# 232 Text feature [observations] present in test data point [True]
# 234 Text feature [additional] present in test data point [True]
# 242 Text feature [phosphate] present in test data point [True]
# 244 Text feature [44] present in test data point [True]
# 246 Text feature [addition] present in test data point [True]
# 248 Text feature [ras] present in test data point [True]
# 249 Text feature [express] present in test data point [True]
# 252 Text feature [supplemental] present in test data point [True]
# 254 Text feature [wt] present in test data point [True]
# 255 Text feature [regulated] present in test data point [True]
# 257 Text feature [inhibitor] present in test data point [True]
# 264 Text feature [higher] present in test data point [True]
# 265 Text feature [frequent] present in test data point [True]
# 269 Text feature [37] present in test data point [True]
# 270 Text feature [cells] present in test data point [True]
# 271 Text feature [concentrations] present in test data point [True]
# 273 Text feature [demonstrated] present in test data point [True]
# 275 Text feature [leading] present in test data point [True]
# 277 Text feature [promoter] present in test data point [True]
# 279 Text feature [interestingly] present in test data point [True]
# 280 Text feature [membrane] present in test data point [True]
# 281 Text feature [form] present in test data point [True]
# 283 Text feature [plasma] present in test data point [True]
# 288 Text feature [blood] present in test data point [True]
# 290 Text feature [sirna] present in test data point [True]
# 292 Text feature [lesions] present in test data point [True]
# 293 Text feature [formed] present in test data point [True]
# 296 Text feature [raf] present in test data point [True]
# 299 Text feature [assessed] present in test data point [True]
# 305 Text feature [clinically] present in test data point [True]
# 306 Text feature [lung] present in test data point [True]
# 311 Text feature [contribute] present in test data point [True]
# 319 Text feature [factors] present in test data point [True]
# 320 Text feature [kit] present in test data point [True]
# 325 Text feature [similar] present in test data point [True]
# 327 Text feature [72] present in test data point [True]
# 329 Text feature [colonies] present in test data point [True]
# 331 Text feature [total] present in test data point [True]
# 335 Text feature [61] present in test data point [True]
# 338 Text feature [size] present in test data point [True]
# 340 Text feature [cultured] present in test data point [True]
# 341 Text feature [ph] present in test data point [True]
# 342 Text feature [various] present in test data point [True]
# 343 Text feature [comparison] present in test data point [True]
# 346 Text feature [phosphorylation] present in test data point [True]
# 348 Text feature [note] present in test data point [True]
# 349 Text feature [s3] present in test data point [True]
# 350 Text feature [previously] present in test data point [True]
# 355 Text feature [carried] present in test data point [True]
# 356 Text feature [lead] present in test data point [True]
# 363 Text feature [mediated] present in test data point [True]
# 365 Text feature [gain] present in test data point [True]
# 366 Text feature [elevated] present in test data point [True]
# 368 Text feature [serum] present in test data point [True]
# 370 Text feature [published] present in test data point [True]
# 371 Text feature [university] present in test data point [True]
# 373 Text feature [harboring] present in test data point [True]
# 375 Text feature [possibility] present in test data point [True]
# 377 Text feature [mechanisms] present in test data point [True]
# 378 Text feature [less] present in test data point [True]
# 379 Text feature [added] present in test data point [True]
# 380 Text feature [four] present in test data point [True]
# 386 Text feature [reaction] present in test data point [True]
# 389 Text feature [high] present in test data point [True]
# 392 Text feature [epithelial] present in test data point [True]
# 395 Text feature [org] present in test data point [True]
# 396 Text feature [occur] present in test data point [True]
# 397 Text feature [contrast] present in test data point [True]
# 398 Text feature [initial] present in test data point [True]
# 402 Text feature [survival] present in test data point [True]
# 405 Text feature [mutant] present in test data point [True]
# 406 Text feature [caused] present in test data point [True]
# 408 Text feature [prior] present in test data point [True]
# 409 Text feature [grade] present in test data point [True]
# 410 Text feature [day] present in test data point [True]
# 414 Text feature [vector] present in test data point [True]
# 415 Text feature [supplementary] present in test data point [True]
# 416 Text feature [well] present in test data point [True]
# 420 Text feature [somatic] present in test data point [True]
# 422 Text feature [mechanism] present in test data point [True]
# 423 Text feature [24] present in test data point [True]
# 425 Text feature [sequences] present in test data point [True]
# 426 Text feature [specimens] present in test data point [True]
# 427 Text feature [subsequent] present in test data point [True]
# 429 Text feature [open] present in test data point [True]
# 436 Text feature [3a] present in test data point [True]
# 438 Text feature [receptors] present in test data point [True]
# 441 Text feature [transformation] present in test data point [True]
# 446 Text feature [frequently] present in test data point [True]
# 451 Text feature [use] present in test data point [True]
# 452 Text feature [clones] present in test data point [True]
# 457 Text feature [region] present in test data point [True]
# 459 Text feature [probe] present in test data point [True]
# 463 Text feature [sensitive] present in test data point [True]
# 466 Text feature [leukemia] present in test data point [True]
# 470 Text feature [43] present in test data point [True]
# 471 Text feature [compared] present in test data point [True]
# 474 Text feature [akt1] present in test data point [True]
# 475 Text feature [frequency] present in test data point [True]
# 477 Text feature [position] present in test data point [True]
# 478 Text feature [reverse] present in test data point [True]
# 479 Text feature [differentiation] present in test data point [True]
# 480 Text feature [effective] present in test data point [True]
# 481 Text feature [median] present in test data point [True]
# 482 Text feature [available] present in test data point [True]
# 483 Text feature [regulatory] present in test data point [True]
# 485 Text feature [tumors] present in test data point [True]
# 486 Text feature [recurrent] present in test data point [True]
# 489 Text feature [mouse] present in test data point [True]
# 495 Text feature [system] present in test data point [True]
# 496 Text feature [tumor] present in test data point [True]
# Out of the top  500  features  170 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 101
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[3.230e-02 3.136e-01 7.000e-04 1.018e-01 5.600e-03 1.500e-03 5.405e-01
#   3.900e-03 3.000e-04]]
# Actual Class : 2
# --------------------------------------------------
# 8 Text feature [overexpression] present in test data point [True]
# 20 Text feature [activation] present in test data point [True]
# 25 Text feature [oncogene] present in test data point [True]
# 28 Text feature [factor] present in test data point [True]
# 32 Text feature [constitutive] present in test data point [True]
# 41 Text feature [2a] present in test data point [True]
# 45 Text feature [pathways] present in test data point [True]
# 50 Text feature [transformed] present in test data point [True]
# 52 Text feature [000] present in test data point [True]
# 59 Text feature [regions] present in test data point [True]
# 61 Text feature [inhibited] present in test data point [True]
# 64 Text feature [activated] present in test data point [True]
# 66 Text feature [phospho] present in test data point [True]
# 68 Text feature [increased] present in test data point [True]
# 70 Text feature [tissues] present in test data point [True]
# 77 Text feature [de] present in test data point [True]
# 78 Text feature [activate] present in test data point [True]
# 88 Text feature [akt] present in test data point [True]
# 90 Text feature [3b] present in test data point [True]
# 96 Text feature [coding] present in test data point [True]
# 121 Text feature [signaling] present in test data point [True]
# 123 Text feature [transforming] present in test data point [True]
# 130 Text feature [derived] present in test data point [True]
# 139 Text feature [days] present in test data point [True]
# 147 Text feature [oncogenic] present in test data point [True]
# 148 Text feature [fold] present in test data point [True]
# 155 Text feature [per] present in test data point [True]
# 158 Text feature [without] present in test data point [True]
# 159 Text feature [example] present in test data point [True]
# 160 Text feature [increase] present in test data point [True]
# 168 Text feature [sites] present in test data point [True]
# 173 Text feature [driven] present in test data point [True]
# 174 Text feature [expressing] present in test data point [True]
# 185 Text feature [gfp] present in test data point [True]
# 194 Text feature [2b] present in test data point [True]
# 203 Text feature [phosphorylated] present in test data point [True]
# 207 Text feature [75] present in test data point [True]
# 214 Text feature [positive] present in test data point [True]
# 218 Text feature [distinct] present in test data point [True]
# 221 Text feature [41] present in test data point [True]
# 222 Text feature [activating] present in test data point [True]
# 225 Text feature [versus] present in test data point [True]
# 226 Text feature [hours] present in test data point [True]
# 227 Text feature [genomic] present in test data point [True]
# 229 Text feature [fig] present in test data point [True]
# 234 Text feature [additional] present in test data point [True]
# 242 Text feature [phosphate] present in test data point [True]
# 244 Text feature [44] present in test data point [True]
# 246 Text feature [addition] present in test data point [True]
# 249 Text feature [express] present in test data point [True]
# 252 Text feature [supplemental] present in test data point [True]
# 255 Text feature [regulated] present in test data point [True]
# 257 Text feature [inhibitor] present in test data point [True]
# 264 Text feature [higher] present in test data point [True]
# 265 Text feature [frequent] present in test data point [True]
# 269 Text feature [37] present in test data point [True]
# 270 Text feature [cells] present in test data point [True]
# 271 Text feature [concentrations] present in test data point [True]
# 273 Text feature [demonstrated] present in test data point [True]
# 277 Text feature [promoter] present in test data point [True]
# 279 Text feature [interestingly] present in test data point [True]
# 281 Text feature [form] present in test data point [True]
# 286 Text feature [transcription] present in test data point [True]
# 288 Text feature [blood] present in test data point [True]
# 292 Text feature [lesions] present in test data point [True]
# 299 Text feature [assessed] present in test data point [True]
# 303 Text feature [include] present in test data point [True]
# 311 Text feature [contribute] present in test data point [True]
# 319 Text feature [factors] present in test data point [True]
# 325 Text feature [similar] present in test data point [True]
# 327 Text feature [72] present in test data point [True]
# 331 Text feature [total] present in test data point [True]
# 335 Text feature [61] present in test data point [True]
# 340 Text feature [cultured] present in test data point [True]
# 343 Text feature [comparison] present in test data point [True]
# 346 Text feature [phosphorylation] present in test data point [True]
# 348 Text feature [note] present in test data point [True]
# 349 Text feature [s3] present in test data point [True]
# 350 Text feature [previously] present in test data point [True]
# 354 Text feature [2012] present in test data point [True]
# 356 Text feature [lead] present in test data point [True]
# 359 Text feature [chain] present in test data point [True]
# 360 Text feature [loop] present in test data point [True]
# 363 Text feature [mediated] present in test data point [True]
# 365 Text feature [gain] present in test data point [True]
# 366 Text feature [elevated] present in test data point [True]
# 368 Text feature [serum] present in test data point [True]
# 370 Text feature [published] present in test data point [True]
# 371 Text feature [university] present in test data point [True]
# 373 Text feature [harboring] present in test data point [True]
# 377 Text feature [mechanisms] present in test data point [True]
# 378 Text feature [less] present in test data point [True]
# 380 Text feature [four] present in test data point [True]
# 389 Text feature [high] present in test data point [True]
# 393 Text feature [kd] present in test data point [True]
# 395 Text feature [org] present in test data point [True]
# 396 Text feature [occur] present in test data point [True]
# 397 Text feature [contrast] present in test data point [True]
# 398 Text feature [initial] present in test data point [True]
# 402 Text feature [survival] present in test data point [True]
# 405 Text feature [mutant] present in test data point [True]
# 406 Text feature [caused] present in test data point [True]
# 408 Text feature [prior] present in test data point [True]
# 409 Text feature [grade] present in test data point [True]
# 410 Text feature [day] present in test data point [True]
# 414 Text feature [vector] present in test data point [True]
# 416 Text feature [well] present in test data point [True]
# 420 Text feature [somatic] present in test data point [True]
# 422 Text feature [mechanism] present in test data point [True]
# 423 Text feature [24] present in test data point [True]
# 425 Text feature [sequences] present in test data point [True]
# 427 Text feature [subsequent] present in test data point [True]
# 431 Text feature [series] present in test data point [True]
# 436 Text feature [3a] present in test data point [True]
# 441 Text feature [transformation] present in test data point [True]
# 446 Text feature [frequently] present in test data point [True]
# 451 Text feature [use] present in test data point [True]
# 457 Text feature [region] present in test data point [True]
# 463 Text feature [sensitive] present in test data point [True]
# 471 Text feature [compared] present in test data point [True]
# 475 Text feature [frequency] present in test data point [True]
# 477 Text feature [position] present in test data point [True]
# 478 Text feature [reverse] present in test data point [True]
# 479 Text feature [differentiation] present in test data point [True]
# 480 Text feature [effective] present in test data point [True]
# 481 Text feature [median] present in test data point [True]
# 482 Text feature [available] present in test data point [True]
# 483 Text feature [regulatory] present in test data point [True]
# 485 Text feature [tumors] present in test data point [True]
# 486 Text feature [recurrent] present in test data point [True]
# 489 Text feature [mouse] present in test data point [True]
# 494 Text feature [positions] present in test data point [True]
# 496 Text feature [tumor] present in test data point [True]
# Out of the top  500  features  133 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1537206507574553
# for C = 0.0001
# Log Loss : 1.1060339100679903
# for C = 0.001
# Log Loss : 1.0954007974770408
# for C = 0.01
# Log Loss : 1.2956214854946833
# for C = 0.1
# Log Loss : 1.7421255027182168
# for C = 1
# Log Loss : 1.8128898500006634
# for C = 10
# Log Loss : 1.8128897197108664
# for C = 100
# Log Loss : 1.8129094777951953
# For values of best alpha =  0.001 The train log loss is: 0.8176496928327427
# For values of best alpha =  0.001 The cross validation log loss is: 1.0954007974770408
# For values of best alpha =  0.001 The test log loss is: 1.065270434324586

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_tfidf, train_y,cv_x_tfidf,cv_y, clf)
# Out:
# Log loss : 1.0954007974770408
# Number of mis-classified points : 0.34774436090225563
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_tfidf,train_y)
test_point_index = 100
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0173 0.083  0.0055 0.0401 0.0074 0.0192 0.823  0.0023 0.0022]]
# Actual Class : 7
# --------------------------------------------------
# 17 Text feature [codon] present in test data point [True]
# 24 Text feature [constitutive] present in test data point [True]
# 25 Text feature [activation] present in test data point [True]
# 26 Text feature [2a] present in test data point [True]
# 27 Text feature [akt] present in test data point [True]
# 35 Text feature [activated] present in test data point [True]
# 36 Text feature [oncogene] present in test data point [True]
# 46 Text feature [000] present in test data point [True]
# 48 Text feature [signaling] present in test data point [True]
# 49 Text feature [factor] present in test data point [True]
# 50 Text feature [inhibited] present in test data point [True]
# 53 Text feature [provided] present in test data point [True]
# 54 Text feature [her2] present in test data point [True]
# 55 Text feature [expressing] present in test data point [True]
# 58 Text feature [enhanced] present in test data point [True]
# 61 Text feature [activate] present in test data point [True]
# 62 Text feature [activating] present in test data point [True]
# 63 Text feature [downstream] present in test data point [True]
# 70 Text feature [pathways] present in test data point [True]
# 73 Text feature [serum] present in test data point [True]
# 74 Text feature [2b] present in test data point [True]
# 75 Text feature [fold] present in test data point [True]
# 76 Text feature [phospho] present in test data point [True]
# 78 Text feature [cdna] present in test data point [True]
# 81 Text feature [signals] present in test data point [True]
# 82 Text feature [transforming] present in test data point [True]
# 83 Text feature [phosphorylated] present in test data point [True]
# 84 Text feature [transformed] present in test data point [True]
# 86 Text feature [increased] present in test data point [True]
# 87 Text feature [raf] present in test data point [True]
# 161 Text feature [adenocarcinoma] present in test data point [True]
# 162 Text feature [3b] present in test data point [True]
# 164 Text feature [stably] present in test data point [True]
# 165 Text feature [bp] present in test data point [True]
# 166 Text feature [oncogenic] present in test data point [True]
# 167 Text feature [approximately] present in test data point [True]
# 169 Text feature [without] present in test data point [True]
# 170 Text feature [overexpression] present in test data point [True]
# 171 Text feature [derived] present in test data point [True]
# 172 Text feature [regions] present in test data point [True]
# 174 Text feature [lung] present in test data point [True]
# 177 Text feature [examined] present in test data point [True]
# 179 Text feature [cells] present in test data point [True]
# 180 Text feature [addition] present in test data point [True]
# 181 Text feature [example] present in test data point [True]
# 186 Text feature [form] present in test data point [True]
# 187 Text feature [s3] present in test data point [True]
# 188 Text feature [61] present in test data point [True]
# 190 Text feature [constitutively] present in test data point [True]
# 191 Text feature [kit] present in test data point [True]
# 192 Text feature [observations] present in test data point [True]
# 193 Text feature [per] present in test data point [True]
# 195 Text feature [express] present in test data point [True]
# 196 Text feature [phosphate] present in test data point [True]
# 197 Text feature [de] present in test data point [True]
# 198 Text feature [extracellular] present in test data point [True]
# 199 Text feature [frequent] present in test data point [True]
# 264 Text feature [gfp] present in test data point [True]
# 265 Text feature [transduced] present in test data point [True]
# 266 Text feature [demonstrated] present in test data point [True]
# 273 Text feature [primer] present in test data point [True]
# 274 Text feature [medium] present in test data point [True]
# 275 Text feature [akt1] present in test data point [True]
# 276 Text feature [phosphorylation] present in test data point [True]
# 277 Text feature [driven] present in test data point [True]
# 279 Text feature [plasma] present in test data point [True]
# 281 Text feature [inhibitor] present in test data point [True]
# 282 Text feature [gain] present in test data point [True]
# 284 Text feature [higher] present in test data point [True]
# 286 Text feature [hours] present in test data point [True]
# 287 Text feature [factors] present in test data point [True]
# 288 Text feature [effective] present in test data point [True]
# 291 Text feature [additional] present in test data point [True]
# 292 Text feature [tyrosine] present in test data point [True]
# 293 Text feature [fig] present in test data point [True]
# 294 Text feature [75] present in test data point [True]
# 295 Text feature [well] present in test data point [True]
# 296 Text feature [mutant] present in test data point [True]
# 299 Text feature [increase] present in test data point [True]
# 301 Text feature [ras] present in test data point [True]
# 302 Text feature [various] present in test data point [True]
# 303 Text feature [lead] present in test data point [True]
# 304 Text feature [concentrations] present in test data point [True]
# 305 Text feature [sensitive] present in test data point [True]
# 306 Text feature [versus] present in test data point [True]
# 307 Text feature [days] present in test data point [True]
# 308 Text feature [wt] present in test data point [True]
# 309 Text feature [promoter] present in test data point [True]
# 310 Text feature [positive] present in test data point [True]
# 311 Text feature [sites] present in test data point [True]
# 314 Text feature [epithelial] present in test data point [True]
# 316 Text feature [prior] present in test data point [True]
# 317 Text feature [transformation] present in test data point [True]
# 318 Text feature [malignant] present in test data point [True]
# 319 Text feature [lesions] present in test data point [True]
# 320 Text feature [less] present in test data point [True]
# 321 Text feature [clinically] present in test data point [True]
# 323 Text feature [possibility] present in test data point [True]
# 324 Text feature [membrane] present in test data point [True]
# 325 Text feature [survival] present in test data point [True]
# 326 Text feature [elevated] present in test data point [True]
# 327 Text feature [reaction] present in test data point [True]
# 328 Text feature [supplemental] present in test data point [True]
# 329 Text feature [leukemia] present in test data point [True]
# 330 Text feature [promote] present in test data point [True]
# 332 Text feature [cultured] present in test data point [True]
# 333 Text feature [occur] present in test data point [True]
# 382 Text feature [cancers] present in test data point [True]
# 383 Text feature [comparison] present in test data point [True]
# 385 Text feature [mechanism] present in test data point [True]
# 386 Text feature [leading] present in test data point [True]
# 388 Text feature [found] present in test data point [True]
# 389 Text feature [formed] present in test data point [True]
# 390 Text feature [previously] present in test data point [True]
# 391 Text feature [41] present in test data point [True]
# 393 Text feature [region] present in test data point [True]
# 394 Text feature [erk] present in test data point [True]
# 395 Text feature [signalling] present in test data point [True]
# 396 Text feature [receptors] present in test data point [True]
# 397 Text feature [sufficient] present in test data point [True]
# 398 Text feature [harboring] present in test data point [True]
# 399 Text feature [vector] present in test data point [True]
# 400 Text feature [university] present in test data point [True]
# 401 Text feature [d1] present in test data point [True]
# 403 Text feature [frequency] present in test data point [True]
# 404 Text feature [24] present in test data point [True]
# 406 Text feature [diagnosis] present in test data point [True]
# 407 Text feature [interestingly] present in test data point [True]
# 408 Text feature [regulated] present in test data point [True]
# 409 Text feature [carried] present in test data point [True]
# 410 Text feature [caused] present in test data point [True]
# 411 Text feature [44] present in test data point [True]
# 412 Text feature [efficacy] present in test data point [True]
# 413 Text feature [cyclin] present in test data point [True]
# 414 Text feature [pathway] present in test data point [True]
# 415 Text feature [added] present in test data point [True]
# 416 Text feature [use] present in test data point [True]
# 417 Text feature [distinct] present in test data point [True]
# 418 Text feature [strong] present in test data point [True]
# 419 Text feature [plates] present in test data point [True]
# 420 Text feature [domain] present in test data point [True]
# 421 Text feature [corresponding] present in test data point [True]
# 422 Text feature [stage] present in test data point [True]
# 423 Text feature [assessed] present in test data point [True]
# 424 Text feature [mediated] present in test data point [True]
# 425 Text feature [growth] present in test data point [True]
# 426 Text feature [ph] present in test data point [True]
# 427 Text feature [free] present in test data point [True]
# 428 Text feature [blood] present in test data point [True]
# 429 Text feature [total] present in test data point [True]
# 430 Text feature [position] present in test data point [True]
# 431 Text feature [culture] present in test data point [True]
# 432 Text feature [sirna] present in test data point [True]
# 433 Text feature [numbers] present in test data point [True]
# 434 Text feature [72] present in test data point [True]
# 436 Text feature [pi3k] present in test data point [True]
# 437 Text feature [compared] present in test data point [True]
# 440 Text feature [contrast] present in test data point [True]
# 442 Text feature [absence] present in test data point [True]
# 443 Text feature [sequences] present in test data point [True]
# 444 Text feature [involving] present in test data point [True]
# 445 Text feature [download] present in test data point [True]
# 447 Text feature [carcinoma] present in test data point [True]
# 448 Text feature [properties] present in test data point [True]
# 449 Text feature [alk] present in test data point [True]
# 455 Text feature [somatic] present in test data point [True]
# 456 Text feature [fusion] present in test data point [True]
# 457 Text feature [strongly] present in test data point [True]
# 458 Text feature [mouse] present in test data point [True]
# 459 Text feature [mice] present in test data point [True]
# 460 Text feature [14] present in test data point [True]
# 462 Text feature [37] present in test data point [True]
# 463 Text feature [2003] present in test data point [True]
# Out of the top  500  features  173 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 101
no_feature = 500
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0717 0.2945 0.0055 0.1946 0.0227 0.0248 0.3734 0.0059 0.007 ]]
# Actual Class : 2
# --------------------------------------------------
# 24 Text feature [constitutive] present in test data point [True]
# 25 Text feature [activation] present in test data point [True]
# 26 Text feature [2a] present in test data point [True]
# 27 Text feature [akt] present in test data point [True]
# 35 Text feature [activated] present in test data point [True]
# 36 Text feature [oncogene] present in test data point [True]
# 46 Text feature [000] present in test data point [True]
# 48 Text feature [signaling] present in test data point [True]
# 49 Text feature [factor] present in test data point [True]
# 50 Text feature [inhibited] present in test data point [True]
# 55 Text feature [expressing] present in test data point [True]
# 61 Text feature [activate] present in test data point [True]
# 62 Text feature [activating] present in test data point [True]
# 70 Text feature [pathways] present in test data point [True]
# 73 Text feature [serum] present in test data point [True]
# 74 Text feature [2b] present in test data point [True]
# 75 Text feature [fold] present in test data point [True]
# 76 Text feature [phospho] present in test data point [True]
# 82 Text feature [transforming] present in test data point [True]
# 83 Text feature [phosphorylated] present in test data point [True]
# 84 Text feature [transformed] present in test data point [True]
# 86 Text feature [increased] present in test data point [True]
# 162 Text feature [3b] present in test data point [True]
# 166 Text feature [oncogenic] present in test data point [True]
# 169 Text feature [without] present in test data point [True]
# 170 Text feature [overexpression] present in test data point [True]
# 171 Text feature [derived] present in test data point [True]
# 172 Text feature [regions] present in test data point [True]
# 178 Text feature [coding] present in test data point [True]
# 179 Text feature [cells] present in test data point [True]
# 180 Text feature [addition] present in test data point [True]
# 181 Text feature [example] present in test data point [True]
# 185 Text feature [tissues] present in test data point [True]
# 186 Text feature [form] present in test data point [True]
# 187 Text feature [s3] present in test data point [True]
# 188 Text feature [61] present in test data point [True]
# 193 Text feature [per] present in test data point [True]
# 195 Text feature [express] present in test data point [True]
# 196 Text feature [phosphate] present in test data point [True]
# 197 Text feature [de] present in test data point [True]
# 199 Text feature [frequent] present in test data point [True]
# 264 Text feature [gfp] present in test data point [True]
# 265 Text feature [transduced] present in test data point [True]
# 266 Text feature [demonstrated] present in test data point [True]
# 276 Text feature [phosphorylation] present in test data point [True]
# 277 Text feature [driven] present in test data point [True]
# 280 Text feature [positions] present in test data point [True]
# 281 Text feature [inhibitor] present in test data point [True]
# 282 Text feature [gain] present in test data point [True]
# 284 Text feature [higher] present in test data point [True]
# 286 Text feature [hours] present in test data point [True]
# 287 Text feature [factors] present in test data point [True]
# 288 Text feature [effective] present in test data point [True]
# 290 Text feature [kd] present in test data point [True]
# 291 Text feature [additional] present in test data point [True]
# 292 Text feature [tyrosine] present in test data point [True]
# 293 Text feature [fig] present in test data point [True]
# 294 Text feature [75] present in test data point [True]
# 295 Text feature [well] present in test data point [True]
# 296 Text feature [mutant] present in test data point [True]
# 299 Text feature [increase] present in test data point [True]
# 303 Text feature [lead] present in test data point [True]
# 304 Text feature [concentrations] present in test data point [True]
# 305 Text feature [sensitive] present in test data point [True]
# 306 Text feature [versus] present in test data point [True]
# 307 Text feature [days] present in test data point [True]
# 309 Text feature [promoter] present in test data point [True]
# 310 Text feature [positive] present in test data point [True]
# 311 Text feature [sites] present in test data point [True]
# 313 Text feature [cdk4] present in test data point [True]
# 316 Text feature [prior] present in test data point [True]
# 317 Text feature [transformation] present in test data point [True]
# 319 Text feature [lesions] present in test data point [True]
# 320 Text feature [less] present in test data point [True]
# 322 Text feature [mutants] present in test data point [True]
# 325 Text feature [survival] present in test data point [True]
# 326 Text feature [elevated] present in test data point [True]
# 328 Text feature [supplemental] present in test data point [True]
# 330 Text feature [promote] present in test data point [True]
# 332 Text feature [cultured] present in test data point [True]
# 333 Text feature [occur] present in test data point [True]
# 382 Text feature [cancers] present in test data point [True]
# 383 Text feature [comparison] present in test data point [True]
# 385 Text feature [mechanism] present in test data point [True]
# 388 Text feature [found] present in test data point [True]
# 390 Text feature [previously] present in test data point [True]
# 391 Text feature [41] present in test data point [True]
# 393 Text feature [region] present in test data point [True]
# 397 Text feature [sufficient] present in test data point [True]
# 398 Text feature [harboring] present in test data point [True]
# 399 Text feature [vector] present in test data point [True]
# 400 Text feature [university] present in test data point [True]
# 401 Text feature [d1] present in test data point [True]
# 403 Text feature [frequency] present in test data point [True]
# 404 Text feature [24] present in test data point [True]
# 405 Text feature [chain] present in test data point [True]
# 407 Text feature [interestingly] present in test data point [True]
# 408 Text feature [regulated] present in test data point [True]
# 410 Text feature [caused] present in test data point [True]
# 411 Text feature [44] present in test data point [True]
# 413 Text feature [cyclin] present in test data point [True]
# 414 Text feature [pathway] present in test data point [True]
# 416 Text feature [use] present in test data point [True]
# 417 Text feature [distinct] present in test data point [True]
# 418 Text feature [strong] present in test data point [True]
# 420 Text feature [domain] present in test data point [True]
# 421 Text feature [corresponding] present in test data point [True]
# 422 Text feature [stage] present in test data point [True]
# 423 Text feature [assessed] present in test data point [True]
# 424 Text feature [mediated] present in test data point [True]
# 425 Text feature [growth] present in test data point [True]
# 427 Text feature [free] present in test data point [True]
# 428 Text feature [blood] present in test data point [True]
# 429 Text feature [total] present in test data point [True]
# 430 Text feature [position] present in test data point [True]
# 433 Text feature [numbers] present in test data point [True]
# 434 Text feature [72] present in test data point [True]
# 437 Text feature [compared] present in test data point [True]
# 440 Text feature [contrast] present in test data point [True]
# 441 Text feature [include] present in test data point [True]
# 442 Text feature [absence] present in test data point [True]
# 443 Text feature [sequences] present in test data point [True]
# 448 Text feature [properties] present in test data point [True]
# 452 Text feature [transcription] present in test data point [True]
# 455 Text feature [somatic] present in test data point [True]
# 456 Text feature [fusion] present in test data point [True]
# 457 Text feature [strongly] present in test data point [True]
# 458 Text feature [mouse] present in test data point [True]
# 459 Text feature [mice] present in test data point [True]
# 460 Text feature [14] present in test data point [True]
# 462 Text feature [37] present in test data point [True]
# 463 Text feature [2003] present in test data point [True]
# Out of the top  500  features  132 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With TFIDF VECTORIZATION)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_tfidf, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_tfidf, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.235112872421281
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2752540412020867
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.228520639630347
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2675260139750633
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2243358247606788
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2646619930668437
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.223385831458838
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.263069308283511
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.225273919988286
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.260765807816253
# For values of best estimator =  1000 The train log loss is: 0.863598471114363
# For values of best estimator =  1000 The cross validation log loss is: 1.2233858314588382
# For values of best estimator =  1000 The test log loss is: 1.1596115102670823

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (TFIDF VECTORIZATION)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y,cv_x_tfidf,cv_y, clf)
# Out:
# Log loss : 1.2233858314588382
# Number of mis-classified points : 0.43796992481203006
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0791 0.1818 0.0158 0.0501 0.0433 0.036  0.5738 0.0133 0.0069]]
# Actual Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [suppressor] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [inhibitors] present in test data point [True]
# 6 Text feature [activated] present in test data point [True]
# 7 Text feature [loss] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [phosphorylation] present in test data point [True]
# 12 Text feature [constitutive] present in test data point [True]
# 13 Text feature [pten] present in test data point [True]
# 14 Text feature [oncogenic] present in test data point [True]
# 17 Text feature [erk] present in test data point [True]
# 18 Text feature [inhibitor] present in test data point [True]
# 20 Text feature [protein] present in test data point [True]
# 21 Text feature [akt] present in test data point [True]
# 23 Text feature [therapy] present in test data point [True]
# 25 Text feature [cells] present in test data point [True]
# 26 Text feature [extracellular] present in test data point [True]
# 27 Text feature [therapeutic] present in test data point [True]
# 28 Text feature [constitutively] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 30 Text feature [stability] present in test data point [True]
# 31 Text feature [receptor] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 35 Text feature [functional] present in test data point [True]
# 37 Text feature [proteins] present in test data point [True]
# 38 Text feature [activate] present in test data point [True]
# 39 Text feature [repair] present in test data point [True]
# 40 Text feature [signaling] present in test data point [True]
# 41 Text feature [trials] present in test data point [True]
# 42 Text feature [expression] present in test data point [True]
# 44 Text feature [drug] present in test data point [True]
# 45 Text feature [phospho] present in test data point [True]
# 50 Text feature [treated] present in test data point [True]
# 51 Text feature [defective] present in test data point [True]
# 52 Text feature [efficacy] present in test data point [True]
# 53 Text feature [transforming] present in test data point [True]
# 54 Text feature [classified] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 57 Text feature [ovarian] present in test data point [True]
# 58 Text feature [tagged] present in test data point [True]
# 59 Text feature [predicted] present in test data point [True]
# 60 Text feature [resistance] present in test data point [True]
# 61 Text feature [clinical] present in test data point [True]
# 63 Text feature [inhibited] present in test data point [True]
# 65 Text feature [months] present in test data point [True]
# 66 Text feature [inactivation] present in test data point [True]
# 67 Text feature [functions] present in test data point [True]
# 68 Text feature [phosphatase] present in test data point [True]
# 69 Text feature [oncogene] present in test data point [True]
# 70 Text feature [downstream] present in test data point [True]
# 71 Text feature [mammalian] present in test data point [True]
# 72 Text feature [kinases] present in test data point [True]
# 73 Text feature [patients] present in test data point [True]
# 74 Text feature [assays] present in test data point [True]
# 75 Text feature [null] present in test data point [True]
# 77 Text feature [damage] present in test data point [True]
# 78 Text feature [lines] present in test data point [True]
# 80 Text feature [catalytic] present in test data point [True]
# 82 Text feature [ic50] present in test data point [True]
# 83 Text feature [stimulation] present in test data point [True]
# 84 Text feature [expected] present in test data point [True]
# 85 Text feature [type] present in test data point [True]
# 86 Text feature [response] present in test data point [True]
# 87 Text feature [p53] present in test data point [True]
# 89 Text feature [expressing] present in test data point [True]
# 91 Text feature [dna] present in test data point [True]
# 92 Text feature [serum] present in test data point [True]
# 93 Text feature [risk] present in test data point [True]
# 97 Text feature [factor] present in test data point [True]
# 98 Text feature [ras] present in test data point [True]
# 99 Text feature [nuclear] present in test data point [True]
# Out of the top  100  features  75 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 101
no_feature = 100
predicted_cls = sig_clf.predict(test_x_tfidf[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_tfidf[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.2814 0.1186 0.0149 0.1328 0.0585 0.0466 0.2826 0.0449 0.0197]]
# Actuall Class : 2
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 2 Text feature [suppressor] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [tyrosine] present in test data point [True]
# 5 Text feature [inhibitors] present in test data point [True]
# 6 Text feature [activated] present in test data point [True]
# 7 Text feature [loss] present in test data point [True]
# 8 Text feature [function] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [phosphorylation] present in test data point [True]
# 11 Text feature [missense] present in test data point [True]
# 12 Text feature [constitutive] present in test data point [True]
# 13 Text feature [pten] present in test data point [True]
# 14 Text feature [oncogenic] present in test data point [True]
# 18 Text feature [inhibitor] present in test data point [True]
# 19 Text feature [yeast] present in test data point [True]
# 20 Text feature [protein] present in test data point [True]
# 21 Text feature [akt] present in test data point [True]
# 22 Text feature [pathogenic] present in test data point [True]
# 23 Text feature [therapy] present in test data point [True]
# 24 Text feature [variants] present in test data point [True]
# 25 Text feature [cells] present in test data point [True]
# 27 Text feature [therapeutic] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 30 Text feature [stability] present in test data point [True]
# 31 Text feature [receptor] present in test data point [True]
# 34 Text feature [cell] present in test data point [True]
# 35 Text feature [functional] present in test data point [True]
# 37 Text feature [proteins] present in test data point [True]
# 38 Text feature [activate] present in test data point [True]
# 40 Text feature [signaling] present in test data point [True]
# 41 Text feature [trials] present in test data point [True]
# 42 Text feature [expression] present in test data point [True]
# 44 Text feature [drug] present in test data point [True]
# 45 Text feature [phospho] present in test data point [True]
# 50 Text feature [treated] present in test data point [True]
# 53 Text feature [transforming] present in test data point [True]
# 55 Text feature [inhibition] present in test data point [True]
# 58 Text feature [tagged] present in test data point [True]
# 61 Text feature [clinical] present in test data point [True]
# 63 Text feature [inhibited] present in test data point [True]
# 66 Text feature [inactivation] present in test data point [True]
# 67 Text feature [functions] present in test data point [True]
# 68 Text feature [phosphatase] present in test data point [True]
# 69 Text feature [oncogene] present in test data point [True]
# 72 Text feature [kinases] present in test data point [True]
# 73 Text feature [patients] present in test data point [True]
# 77 Text feature [damage] present in test data point [True]
# 78 Text feature [lines] present in test data point [True]
# 79 Text feature [substitutions] present in test data point [True]
# 80 Text feature [catalytic] present in test data point [True]
# 84 Text feature [expected] present in test data point [True]
# 85 Text feature [type] present in test data point [True]
# 87 Text feature [p53] present in test data point [True]
# 89 Text feature [expressing] present in test data point [True]
# 91 Text feature [dna] present in test data point [True]
# 92 Text feature [serum] present in test data point [True]
# 93 Text feature [risk] present in test data point [True]
# 97 Text feature [factor] present in test data point [True]
# Out of the top  100  features  60 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.081941755886502
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.7207367394538933
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.623370002445087
# for n_estimators = 10 and max depth =  10
# Log Loss : 2.22615119402668
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.8405013027215684
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.5361509040090977
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.5018390347281056
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.803768801789377
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.6970962456744565
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.559627483409318
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.4022796311847718
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.7255626011083018
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6865463236103346
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.5360456463150995
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.3968576853574448
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.7399464872839736
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.7303779263888754
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.5866164713334416
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.41939329864953
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.7503658022188098
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.7149744983731192
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.5991069332017531
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.412966037761224
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.7157318928971086
# For values of best alpha =  200 The train log loss is: 0.05390541374542439
# For values of best alpha =  200 The cross validation log loss is: 1.3968576853574448
# For values of best alpha =  200 The test log loss is: 1.317742432523379

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3968576853574448
# Number of mis-classified points : 0.4924812030075188
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 100
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[2.500e-03 1.125e-01 1.100e-03 3.300e-03 8.000e-04 3.800e-03 8.732e-01
#   1.300e-03 1.300e-03]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0502 0.3364 0.217  0.0566 0.0329 0.04   0.0576 0.121  0.0882]]
# Actual Class : 3
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_tfidf, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_tfidf, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_tfidf, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_tfidf, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_tfidf))))
sig_clf2.fit(train_x_tfidf, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_tfidf))))
sig_clf3.fit(train_x_tfidf, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_tfidf))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_tfidf, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.05
# Support vector machines : Log Loss: 1.81
# Naive Bayes : Log Loss: 1.20
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.038
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.523
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.152
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.169
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.276

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_tfidf, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_tfidf))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_tfidf))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_tfidf))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_tfidf))
# Out:
# Log loss (train) on the stacking classifier : 0.8245373295270003
# Log loss (CV) on the stacking classifier : 1.1519609039608347
# Log loss (test) on the stacking classifier : 1.118923173824635
# Number of missclassified point : 0.3609022556390977
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_tfidf, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_tfidf)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_tfidf)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_tfidf)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_tfidf)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_tfidf))
# Out:
# Log loss (train) on the VotingClassifier : 0.9681122592924005
# Log loss (CV) on the VotingClassifier : 1.203080568039449
# Log loss (test) on the VotingClassifier : 1.1733150612888474
# Number of missclassified point : 0.3609022556390977
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>Logistic regression with CountVectorizer Features, including both unigrams and bigrams

# %%
# one-hot encoding of Gene feature.
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]
gene_vectorizer = CountVectorizer(ngram_range=(1,2))
train_gene_feature_bow = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_bow = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_bow = gene_vectorizer.transform(cv_df['Gene'])
variation_vectorizer = CountVectorizer(ngram_range=(1,2))
train_variation_feature_bow = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_bow = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_bow = variation_vectorizer.transform(cv_df['Variation'])
text_vectorizer = CountVectorizer(min_df=3 , ngram_range=(1,2))
train_text_feature_bow = text_vectorizer.fit_transform(train_df['TEXT'])
# don't forget to normalize every feature
train_text_feature_bow = normalize(train_text_feature_bow, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_bow = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_bow = normalize(test_text_feature_bow, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_bow = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_bow = normalize(cv_text_feature_bow, axis=0)


train_gene_var_bow = hstack((train_gene_feature_bow,train_variation_feature_bow))
test_gene_var_bow = hstack((test_gene_feature_bow,test_variation_feature_bow))
cv_gene_var_bow = hstack((cv_gene_feature_bow,cv_variation_feature_bow))

train_x_bow = hstack((train_gene_var_bow, train_text_feature_bow)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_bow = hstack((test_gene_var_bow, test_text_feature_bow)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_bow = hstack((cv_gene_var_bow, cv_text_feature_bow)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_bow, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_bow, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_bow)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_bow, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_bow, train_y)

predict_y = sig_clf.predict_proba(train_x_bow)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_bow)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_bow)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.57129210650876
# for alpha = 1e-05
# Log Loss : 1.569525965992749
# for alpha = 0.0001
# Log Loss : 1.559657728241279
# for alpha = 0.001
# Log Loss : 1.524936781022135
# for alpha = 0.01
# Log Loss : 1.1778626189026735
# for alpha = 0.1
# Log Loss : 1.2206466439856616
# for alpha = 1
# Log Loss : 1.3352581015369749
# for alpha = 10
# Log Loss : 1.43347467973867
# for alpha = 100
# Log Loss : 1.4537794541860412
# For values of best alpha =  0.01 The train log loss is: 0.9150791808537795
# For values of best alpha =  0.01 The cross validation log loss is: 1.1778626189026735
# For values of best alpha =  0.01 The test log loss is: 1.171364854394799

# %% [markdown]
# <h5>Testing the model with best hyper paramters<h5>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 1.2377124824021637
# Number of mis-classified points : 0.40789473684210525
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_bow.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>InCorrectly Classified point<h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_bow,train_y)
test_point_index = 101
no_feature = 500
predicted_cls = sig_clf.predict(test_x_bow[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_bow[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.1262 0.1162 0.0171 0.0954 0.0426 0.0266 0.5626 0.0066 0.0067]]
# Actual Class : 2
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %% [markdown]
# <h5>Correctly Classified point<h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_bow,train_y)
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_bow[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_bow[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0471 0.1371 0.0079 0.0216 0.0093 0.0011 0.7457 0.0247 0.0056]]
# Actual Class : 7
# --------------------------------------------------
# 55 Text feature [oncogene] present in test data point [True]
# 212 Text feature [tpa] present in test data point [True]
# 326 Text feature [skov3] present in test data point [True]
# 371 Text feature [unsuspected] present in test data point [True]
# Out of the top  500  features  4 are present in query point

# %% [markdown]
# ### Feature Engineering

# %%
train_df['Gene_Variation']=train_df['Gene']+train_df['Variation']
train_df.Gene_Variation = train_df.Gene_Variation.str.replace('\s+', '_')
tfidfVectorizer = TfidfVectorizer(max_features=1000)
text2 = tfidfVectorizer.fit_transform(train_df['Gene_Variation'].values)
gene_variation_features = tfidfVectorizer.get_feature_names()

train_text = tfidfVectorizer.transform(train_df['TEXT'])
test_text = tfidfVectorizer.transform(test_df['TEXT'])
cv_text = tfidfVectorizer.transform(cv_df['TEXT'])

# %%
from scipy.sparse import hstack
train_gene_var_tfidf = hstack((train_gene_feature_tfidf,train_variation_feature_tfidf))
test_gene_var_tfidf = hstack((test_gene_feature_tfidf,test_variation_feature_tfidf))
cv_gene_var_tfidf = hstack((cv_gene_feature_tfidf,cv_variation_feature_tfidf))

# Adding the train_text feature
train_x_tfidf = hstack((train_gene_var_tfidf, train_text))
train_x_tfidf = hstack((train_x_tfidf, train_text_feature_tfidf))
train_x_tfidfFE=np.sqrt(train_x_tfidf)
#train_x_tfidfFElog = np.log(train_x_tfidf)
train_x_tfidf = hstack((train_x_tfidf, train_x_tfidfFE)).tocsr()
#train_x_tfidf = hstack((train_x_tfidf, train_x_tfidfFElog)).tocsr()
train_y = np.array(list(train_df['Class']))
# Adding the test_text feature
test_x_tfidf = hstack((test_gene_var_tfidf, test_text))
test_x_tfidf = hstack((test_x_tfidf, test_text_feature_tfidf))
test_x_tfidfFE=np.sqrt(test_x_tfidf)
#test_x_tfidfFElog=np.log(test_x_tfidf)
test_x_tfidf = hstack((test_x_tfidf, test_x_tfidfFE)).tocsr()
#test_x_tfidf = hstack((test_x_tfidf, test_x_tfidfFElog)).tocsr()
test_y = np.array(list(test_df['Class']))

# Adding the cv_text feature
cv_x_tfidf = hstack((cv_gene_var_tfidf, cv_text))
cv_x_tfidf = hstack((cv_x_tfidf, cv_text_feature_tfidf))
cv_x_tfidfFE=np.sqrt(cv_x_tfidf)
#cv_x_tfidfFElog=np.log(cv_x_tfidf)
cv_x_tfidf = hstack((cv_x_tfidf, cv_x_tfidfFE)).tocsr()
#cv_x_tfidf = hstack((cv_x_tfidf, cv_x_tfidfFElog)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10**x for x in range(-6, 4)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_tfidf, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_tfidf, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_tfidf)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=34)
clf.fit(train_x_tfidf, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_tfidf, train_y)

predict_y = sig_clf.predict_proba(train_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_tfidf)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.0318682355766922
# for alpha = 1e-05
# Log Loss : 1.0563085686514255
# for alpha = 0.0001
# Log Loss : 1.0436538301565703
# for alpha = 0.001
# Log Loss : 1.0001255632179147
# for alpha = 0.01
# Log Loss : 1.1041855422936133
# for alpha = 0.1
# Log Loss : 1.5467017039011979
# for alpha = 1
# Log Loss : 1.8645057354797172
# for alpha = 10
# Log Loss : 1.8855412197573003
# for alpha = 100
# Log Loss : 1.8870966687702324
# for alpha = 1000
# Log Loss : 1.8872490090153728
# For values of best alpha =  0.001 The train log loss is: 0.6190094570964239
# For values of best alpha =  0.001 The cross validation log loss is: 0.9997162783649047
# For values of best alpha =  0.001 The test log loss is: 0.9519395659496341

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=34)
predict_and_plot_confusion_matrix(train_x_tfidf, train_y, cv_x_tfidf, cv_y, clf)
# Out:
# Log loss : 0.9997162783649047
# Number of mis-classified points : 0.3458646616541353
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
from prettytable import PrettyTable
x=PrettyTable()
x.field_names=['Model','Train','CV','Test','Misclassification']
x.add_row(['Random Model','-','2.516','2.450','-'])
x.add_row(['Naive Bayes',0.772,1.204,1.151,39.47])
x.add_row(['KNN (Response Coding)',0.641,1.034,0.995,'35.90'])
x.add_row(['Logistic Regression (Class Balancing)','0.602','1.040','0.960',33.08])
x.add_row(['Logistic Regression (Without Class Balancing)','0.597',1.084,0.976,34.58])
x.add_row(['SVM',0.817,1.095,1.065,34.77])
x.add_row(['Random Forest(TFIDF)','0.863',1.223,1.159,43.79])
x.add_row(['Random Forest(Responce Coding)','0.053','1.396','1.317',49.24])
x.add_row(['Stacking','0.824',1.151,'1.118',36.09])
x.add_row(['Maximum Voting Classifier',0.968,1.203,1.173,36.09])
x.add_row(['Logistic Regression (One Hot Coding)',0.915,1.177,1.171,40.78])
x.add_row(['*********************************************','*****','*****','*****','*****************'])
x.add_row(['Feature Engineering Section','****','****','*****','*****************'])
x.add_row(['*********************************************','*****','*****','*****','*****************'])
x.add_row(['Logistic Regression (Class Balancing)','0.619',0.999,0.951,'34.58'])
print(x)
# Out:
# +-----------------------------------------------+-------+-------+-------+-------------------+
# |                     Model                     | Train |   CV  |  Test | Misclassification |
# +-----------------------------------------------+-------+-------+-------+-------------------+
# |                  Random Model                 |   -   | 2.516 | 2.450 |         -         |
# |                  Naive Bayes                  | 0.772 | 1.204 | 1.151 |       39.47       |
# |             KNN (Response Coding)             | 0.641 | 1.034 | 0.995 |       35.90       |
# |     Logistic Regression (Class Balancing)     | 0.602 | 1.040 | 0.960 |       33.08       |
# | Logistic Regression (Without Class Balancing) | 0.597 | 1.084 | 0.976 |       34.58       |
# |                      SVM                      | 0.817 | 1.095 | 1.065 |       34.77       |
# |              Random Forest(TFIDF)             | 0.863 | 1.223 | 1.159 |       43.79       |
# |         Random Forest(Responce Coding)        | 0.053 | 1.396 | 1.317 |       49.24       |
# |                    Stacking                   | 0.824 | 1.151 | 1.118 |       36.09       |
# |           Maximum Voting Classifier           | 0.968 | 1.203 | 1.173 |       36.09       |
# |      Logistic Regression (One Hot Coding)     | 0.915 | 1.177 | 1.171 |       40.78       |
# | ********************************************* | ***** | ***** | ***** | ***************** |
# |          Feature Engineering Section          |  **** |  **** | ***** | ***************** |
# | ********************************************* | ***** | ***** | ***** | ***************** |
# |     Logistic Regression (Class Balancing)     | 0.619 | 0.999 | 0.951 |       34.58       |
# +-----------------------------------------------+-------+-------+-------+-------------------+

# %% [markdown]
# ### Conclusions:

# %% [markdown]
# <b> <ul><li>1. In this Notebook we first did Univariate Analysis on Our Features<br>
#     <li> 2. After That we used <span style="color:Magenta">Tfidf Vectorization</span> And <span style="color:Magenta">Response Coding</span> to Train our models<br>
#     <li>3. Then we Train Different Models Using our Tfidf Vectorization And Response Coding<br>
#         <ul>
#             <li>We took only 1000 important features from tfidf
#         </ul>
#     <li>4. According to log loss and misclassification points <span style="color:green">Logistic Regression with class Balancing</span> was our best model<br>
#    <li> 5.Then we use OnehotCoding on Logistic Regression<br>
#        <ul>
#            <li>As we can see from the above table the log loss is reduced but not that much , therefore we use feature engineering
#        </ul>
#        <li> After using feature engineering we got following conclusions
#     </ul>
#
#    <span style="color:red"> FEATURE ENGINEERING</span></b>
# <b>  <ul>
#     <li>1. We Applied Feature Engineering on our data
#         <li>2. We First Combined Gene And Variation Together
#             <ul>
#                 <li>We took Gene and Variation Data From Dataframe and combined Them together and created a new feature
#             </ul>
#             <li>3. Then we apply sqrt on our data
#                 <ul>
#                     <li>After stacking all of our data using hstack we took the square root of our data and also add it our final data using hstack
#                 </ul>
#                 <li>4. As we can see our log loss is reduced to less than 1 after we apply Feature Engineeringnonour Data<b>
